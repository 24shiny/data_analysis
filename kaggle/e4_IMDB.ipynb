# %%
from tensorflow import keras
from keras.datasets import imdb # text data transformed to integer

(train_input, train_target), (test_input, test_target) = imdb.load_data(num_words=300)

# check their dimension
print(train_input.shape, test_input.shape)
# Out:
# (25000,) (25000,)

# %%
# what does the data look like..
train_input[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  2,
#  2,
#  2,
#  2,
#  65,
#  2,
#  2,
#  66,
#  2,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  2,
#  112,
#  50,
#  2,
#  2,
#  9,
#  35,
#  2,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  2,
#  2,
#  39,
#  4,
#  172,
#  2,
#  2,
#  17,
#  2,
#  38,
#  13,
#  2,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2,
#  19,
#  14,
#  22,
#  4,
#  2,
#  2,
#  2,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  2,
#  38,
#  76,
#  15,
#  13,
#  2,
#  4,
#  22,
#  17,
#  2,
#  17,
#  12,
#  16,
#  2,
#  18,
#  2,
#  5,
#  62,
#  2,
#  12,
#  8,
#  2,
#  8,
#  106,
#  5,
#  4,
#  2,
#  2,
#  16,
#  2,
#  66,
#  2,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  2,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  2,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  2,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  2,
#  15,
#  256,
#  4,
#  2,
#  7,
#  2,
#  5,
#  2,
#  36,
#  71,
#  43,
#  2,
#  2,
#  26,
#  2,
#  2,
#  46,
#  7,
#  4,
#  2,
#  2,
#  13,
#  104,
#  88,
#  4,
#  2,
#  15,
#  297,
#  98,
#  32,
#  2,
#  56,
#  26,
#  141,
#  6,
#  194,
#  2,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  2,
#  26,
#  2,
#  5,
#  144,
#  30,
#  2,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  2,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  2,
#  113,
#  103,
#  32,
#  15,
#  16,
#  2,
#  19,
#  178,
#  32]

# %%
# our goal is to classify each review to either negative (0) or positive (1) one
train_target[:5]
# Out:
# array([1, 0, 0, 1, 0])

# %%
# spare validation set from the train data
from sklearn.model_selection import train_test_split
train_input, val_input, train_target, val_target = train_test_split(train_input, train_target, 
                                                                    test_size=0.3, random_state=42)
# check their dimension
print(train_input.shape, val_input.shape)
# Out:
# (17500,) (7500,)

# %%
# average and median of the length of reviews
import numpy as np
rev_len = np.array([len(i) for i in train_input])
print(np.round(np.mean(rev_len),3), np.median(rev_len))
# Out:
# 239.216 178.0

# %%
import matplotlib.pyplot as plt
plt.hist(rev_len, edgecolor='white', bins=range(1,1600,100))
plt.xlabel('length of reviews')
plt.ylabel('freq')
plt.show()

# %%
# To use 200 words, reviews shorter than that need padding; this can be done by pad_sequences
# then empty space is filled with zero
from keras.preprocessing.sequence import pad_sequences
train_seq = pad_sequences(train_input, maxlen=150, truncating='post') # selection either 'pre' or 'post'
train_seq.shape
# Out:
# (17500, 150)

# %%
# do the same to val_input
val_seq = pad_sequences(val_input, maxlen=150, truncating='post') # selection either 'pre' or 'post'
val_seq.shape
# Out:
# (7500, 150)

# %% [markdown]
# # RNN

# %%
# create a RNN model
model = keras.Sequential()
model.add(keras.layers.SimpleRNN(10, input_shape=(150,300))) # 150 : time step, 300 : # of unique words
model.add(keras.layers.Dense(1, activation='sigmoid')) # sigmoid for binary classification

# here the integer values need one-hot encoding
train_oh = keras.utils.to_categorical(train_seq)
train_oh.shape
# Out:
# (17500, 150, 300)

# %%
# do the same to val_seq
val_oh = keras.utils.to_categorical(val_seq)
val_oh.shape
# Out:
# (7500, 150, 300)

# %%
adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy', 'precision'])
checkpoint_cb = keras.callbacks.ModelCheckpoint('best_rnn_imdb.keras', save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
fit = model.fit(train_oh, train_target, epochs=100, batch_size=50,
                   validation_data=(val_oh, val_target),
                   callbacks=[checkpoint_cb, early_stopping_cb], verbose=1)
# Out:
# Epoch 1/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.5008 - loss: 0.7067 - precision: 0.5002 - val_accuracy: 0.5141 - val_loss: 0.7006 - val_precision: 0.5188
# Epoch 2/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5156 - loss: 0.6969 - precision: 0.5188 - val_accuracy: 0.5444 - val_loss: 0.6891 - val_precision: 0.5647
# Epoch 3/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5545 - loss: 0.6858 - precision: 0.5553 - val_accuracy: 0.5849 - val_loss: 0.6763 - val_precision: 0.5829
# Epoch 4/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5996 - loss: 0.6704 - precision: 0.5995 - val_accuracy: 0.6292 - val_loss: 0.6587 - val_precision: 0.6367
# Epoch 5/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6313 - loss: 0.6550 - precision: 0.6280 - val_accuracy: 0.6529 - val_loss: 0.6433 - val_precision: 0.6533
# Epoch 6/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6683 - loss: 0.6344 - precision: 0.6595 - val_accuracy: 0.6653 - val_loss: 0.6306 - val_precision: 0.6964
# Epoch 7/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6925 - loss: 0.6138 - precision: 0.6933 - val_accuracy: 0.6840 - val_loss: 0.6154 - val_precision: 0.6693
# Epoch 8/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7100 - loss: 0.5967 - precision: 0.7049 - val_accuracy: 0.6892 - val_loss: 0.6049 - val_precision: 0.6583
# Epoch 9/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7212 - loss: 0.5795 - precision: 0.7132 - val_accuracy: 0.7077 - val_loss: 0.5850 - val_precision: 0.6941
# Epoch 10/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7330 - loss: 0.5644 - precision: 0.7223 - val_accuracy: 0.7157 - val_loss: 0.5738 - val_precision: 0.7201
# Epoch 11/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7371 - loss: 0.5555 - precision: 0.7321 - val_accuracy: 0.7224 - val_loss: 0.5646 - val_precision: 0.7170
# Epoch 12/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7418 - loss: 0.5469 - precision: 0.7410 - val_accuracy: 0.7193 - val_loss: 0.5628 - val_precision: 0.6945
# Epoch 13/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7493 - loss: 0.5346 - precision: 0.7390 - val_accuracy: 0.7256 - val_loss: 0.5536 - val_precision: 0.7075
# Epoch 14/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7567 - loss: 0.5248 - precision: 0.7476 - val_accuracy: 0.7356 - val_loss: 0.5456 - val_precision: 0.7415
# Epoch 15/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7605 - loss: 0.5200 - precision: 0.7538 - val_accuracy: 0.7328 - val_loss: 0.5411 - val_precision: 0.7225
# Epoch 16/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7589 - loss: 0.5179 - precision: 0.7501 - val_accuracy: 0.7323 - val_loss: 0.5400 - val_precision: 0.7198
# Epoch 17/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7601 - loss: 0.5122 - precision: 0.7547 - val_accuracy: 0.7373 - val_loss: 0.5383 - val_precision: 0.7355
# Epoch 18/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7619 - loss: 0.5086 - precision: 0.7542 - val_accuracy: 0.7355 - val_loss: 0.5366 - val_precision: 0.7234
# Epoch 19/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7700 - loss: 0.5019 - precision: 0.7628 - val_accuracy: 0.7407 - val_loss: 0.5303 - val_precision: 0.7333
# Epoch 20/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7669 - loss: 0.5044 - precision: 0.7579 - val_accuracy: 0.7391 - val_loss: 0.5328 - val_precision: 0.7260
# Epoch 21/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7719 - loss: 0.4962 - precision: 0.7645 - val_accuracy: 0.7419 - val_loss: 0.5266 - val_precision: 0.7319
# Epoch 22/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7735 - loss: 0.4935 - precision: 0.7694 - val_accuracy: 0.7432 - val_loss: 0.5281 - val_precision: 0.7378
# Epoch 23/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7708 - loss: 0.4926 - precision: 0.7644 - val_accuracy: 0.7449 - val_loss: 0.5229 - val_precision: 0.7470
# Epoch 24/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7727 - loss: 0.4871 - precision: 0.7691 - val_accuracy: 0.7440 - val_loss: 0.5238 - val_precision: 0.7368
# Epoch 25/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7753 - loss: 0.4860 - precision: 0.7652 - val_accuracy: 0.7461 - val_loss: 0.5252 - val_precision: 0.7426
# Epoch 26/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7740 - loss: 0.4881 - precision: 0.7697 - val_accuracy: 0.7469 - val_loss: 0.5218 - val_precision: 0.7438
# Epoch 27/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7763 - loss: 0.4855 - precision: 0.7715 - val_accuracy: 0.7452 - val_loss: 0.5217 - val_precision: 0.7521
# Epoch 28/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7742 - loss: 0.4871 - precision: 0.7652 - val_accuracy: 0.7479 - val_loss: 0.5246 - val_precision: 0.7488
# Epoch 29/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7767 - loss: 0.4859 - precision: 0.7702 - val_accuracy: 0.7483 - val_loss: 0.5211 - val_precision: 0.7348
# Epoch 30/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7822 - loss: 0.4777 - precision: 0.7745 - val_accuracy: 0.7487 - val_loss: 0.5225 - val_precision: 0.7374
# Epoch 31/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7842 - loss: 0.4766 - precision: 0.7770 - val_accuracy: 0.7475 - val_loss: 0.5194 - val_precision: 0.7620
# Epoch 32/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7798 - loss: 0.4786 - precision: 0.7737 - val_accuracy: 0.7487 - val_loss: 0.5170 - val_precision: 0.7439
# Epoch 33/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7876 - loss: 0.4685 - precision: 0.7784 - val_accuracy: 0.7487 - val_loss: 0.5245 - val_precision: 0.7446
# Epoch 34/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7818 - loss: 0.4776 - precision: 0.7766 - val_accuracy: 0.7468 - val_loss: 0.5189 - val_precision: 0.7550
# Epoch 35/100
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7809 - loss: 0.4764 - precision: 0.7759 - val_accuracy: 0.7508 - val_loss: 0.5199 - val_precision: 0.7452

# %%
fit.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'precision', 'val_accuracy', 'val_loss', 'val_precision'])

# %%
len(fit.history['loss'])
# Out:
# 9

# %%
plt.plot(range(len(fit.history['loss'])), fit.history['loss'],'.-')
plt.plot(range(len(fit.history['val_loss'])), fit.history['val_loss'],'.-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','val'])
plt.show()

# %%
# what if adding another layers? - make it as functions
def imdb_model(layer):
    model = keras.Sequential()
    if len(layer)==1: # as for a single input
        model.add(layer[0])
    else: # as for an array input
        for i in layer:
            model.add(i)
    # model.add(keras.layers.SimpleRNN(10, input_shape=(150,300))) # 150 : time step, 300 : # of unique words
    model.add(keras.layers.Dense(1, activation='sigmoid')) # sigmoid for binary classification
    return model

def imdb_test(model):
    adam = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy', 'precision'])
    checkpoint_cb = keras.callbacks.ModelCheckpoint('best_rnn_imdb.keras', save_best_only=True)
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
    fit = model.fit(train_oh, train_target, epochs=100, batch_size=50,
                       validation_data=(val_oh, val_target),
                       callbacks=[checkpoint_cb, early_stopping_cb], verbose=0)

    print(fit.history['loss'][-1], fit.history['val_loss'][-1] )
    plt.plot(range(len(fit.history['loss'])), fit.history['loss'],'.-')
    plt.plot(range(len(fit.history['val_loss'])), fit.history['val_loss'],'.-')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['train','val'])
    plt.show()

# %%
model = imdb_model([keras.layers.SimpleRNN(10, input_shape=(150,300))])
imdb_test(model)
# Out:
# 0.48952198028564453 0.5322796106338501

# %%
model.summary()
# Out:
# Model: "sequential_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_30 (SimpleRNN)            │ (None, 10)                  │           3,110 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,365 (36.59 KB)
#  Trainable params: 3,121 (12.19 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6,244 (24.39 KB)

# %%
# use dropout
model = imdb_model([keras.layers.SimpleRNN(10, input_shape=(150,300), dropout=0.3)])
imdb_test(model)
# Out:
# 0.5466446876525879 0.5278965830802917

# %%
# try LSTM
model = imdb_model([keras.layers.LSTM(10, input_shape=(150,300))])
imdb_test(model)
# Out:
# 0.476459264755249 0.49884769320487976

# %%
# use dropout to reduce the overffiting further
model = imdb_model([keras.layers.LSTM(10, input_shape=(150,300), dropout=0.3)])
imdb_test(model)
# Out:
# 0.5317063927650452 0.5111872553825378

# %%
# add one more LSTM layer
model = imdb_model([keras.layers.LSTM(10, input_shape=(150,300), dropout=0.3, return_sequences=True),
                   keras.layers.LSTM(10, dropout=0.3)])
imdb_test(model)
# Out:
# 0.5503273010253906 0.5152484774589539

# %%
model = imdb_model([keras.layers.LSTM(10, input_shape=(150,300), return_sequences=True),
                   keras.layers.LSTM(10)])
imdb_test(model)
# Out:
# 0.48532187938690186 0.5065166354179382

# %%
# try GRU in the same way
model = imdb_model([keras.layers.GRU(10, input_shape=(150,300))])
imdb_test(model)
# Out:
# 0.4717559218406677 0.49701935052871704

# %%
model = imdb_model([keras.layers.GRU(10, input_shape=(150,300), return_sequences=True),
                   keras.layers.GRU(10)])
imdb_test(model)
# Out:
# 0.4885498285293579 0.5098557472229004
